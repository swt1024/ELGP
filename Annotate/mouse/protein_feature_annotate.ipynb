# %% [markdown]
# # Annotate features for proteins.

# %% [markdown]
# ## Step1 Extract all protein.

# %% [markdown]
# ### Step1.1 Extract all protein molecules from a filtered LPPI.

# %%
import pandas as pd

# Example usage
inter_file = 'inter_with_valid_lnc.csv'
inter = pd.read_csv(inter_file)

# Concatenate two columns into a new Series and remove duplicates
molecule = pd.concat([inter['Node_i'], inter['Node_j']]).reset_index(drop=True)
molecule_df = pd.DataFrame(molecule, columns=['molecule'])
molecule_df = molecule_df.drop_duplicates()

protein_file = '../../data/LPPI/mouse/protein_updated.csv'
proteins = pd.read_csv(protein_file)

proteins = proteins[proteins['protein_ID'].isin(molecule_df['molecule'])]

# Export to CSV file
protein_file = 'proteins.csv'
proteins.to_csv(protein_file, index=False)

# %% [markdown]
# ### Step1.2 Annotate MGI ID.

# %%
import pandas as pd

valid_protein = pd.read_csv("proteins.csv", dtype=str)
ID_map = pd.read_csv("../../protein/mouse/MGI_ID_mapping.csv")

protein_with_ID = pd.merge(valid_protein, ID_map, left_on='protein', right_on='Marker Symbol',how="inner")

protein_with_ID = protein_with_ID[['protein','protein_ID','MGI ID']]
protein_with_ID.to_csv('protein_MGI_ID.csv', index=False)

invalid_protein = valid_protein[~valid_protein['protein_ID'].isin(protein_with_ID['protein_ID'])]

invalid_protein.to_csv("no_MGI_ID_protein.csv", index=False)

# %% [markdown]
# ## Step2 Annotate features

# %% [markdown]
# ### Step2.1 Annotate the number of go terms.

# %%
import pandas as pd

def count_gene_go_terms(gaf_file):
    # 读取 GAF 文件（以制表符分隔）
    columns = [
        "DB", "DB_Object_ID", "DB_Object_Symbol", "Qualifier", "GO_ID", "DB_Reference", 
        "Evidence_Code", "With_or_From", "Aspect", "DB_Object_Name", "DB_Object_Synonym",
        "DB_Object_Type", "Taxon", "Date", "Assigned_By", "Annotation_Extension","Gene_Product_Form_ID"
    ]
    
    # 只读取前 15 列（防止 GAF 版本不同导致列数问题）
    df = pd.read_csv(gaf_file, sep="\t", comment="!", header=None, names=columns, usecols=range(15), dtype=str)
    
    # 过滤掉非小鼠数据（taxon:10090）
    df = df[df["Taxon"] == "taxon:10090"]

    # 只保留基因 ID、基因名称和 GO term
    df_filtered = df[["DB_Object_Symbol", "GO_ID"]].drop_duplicates()
    
    # 统计每个基因的 GO term 数量
    gene_go_counts = df_filtered.groupby(["DB_Object_Symbol"])["GO_ID"].nunique().reset_index()
    
    # 重命名列
    gene_go_counts.columns = ["Gene_Symbol", "GO_Term_Count"]
    
    return gene_go_counts

gaf_file = "../../protein/mouse/mgi.gaf"  
gene_go_counts = count_gene_go_terms(gaf_file)

protein = pd.read_csv("proteins.csv", dtype=str)

filtered_gene_go_term_counts = pd.merge(protein, gene_go_counts, left_on='protein', right_on='Gene_Symbol', how='inner')
filtered_gene_go_term_counts = filtered_gene_go_term_counts[['protein_ID','GO_Term_Count']]
# 将结果保存到文件
filtered_gene_go_term_counts.to_csv("protein_go_term_counts.csv", sep=",", index=False)

# %% [markdown]
# ### Step2.2 Annotate the number of orthologs.

# %% [markdown]
# Step2.2.1 Extract gene name.

# %%
import pandas as pd

data = pd.read_csv("proteins.csv")

gene = data[['protein']]

gene.to_csv("protein_name.txt", sep="\t",index=False, header=None)

# %% [markdown]
# Step2.2.2 Get ortholog count using Ensembl REST API

# %%
import requests
import pandas as pd
import time
import os
from concurrent.futures import ThreadPoolExecutor, as_completed

# 配置参数
INPUT_FILE = "protein_name.txt"
OUTPUT_FILE = "all_species_ortholog_counts.csv"
THREADS = 5
MAX_RETRIES = 3
SLEEP_BETWEEN = 0.4
HEADERS = {"Content-Type": "application/json"}

def count_orthologs_by_symbol(symbol):
    url = f"https://rest.ensembl.org/homology/symbol/mus_musculus/{symbol}?type=orthologues"
    for attempt in range(MAX_RETRIES):
        try:
            r = requests.get(url, headers=HEADERS, timeout=15)
            if r.status_code == 200:
                data = r.json()
                homologies = data['data'][0].get('homologies', [])
                count = sum(1 for h in homologies if h['type'] == 'ortholog_one2one')
                return (symbol, count, "OK")
            elif r.status_code == 404:
                return (symbol, 0, "NotFound")
            else:
                print(f"[{symbol}] HTTP {r.status_code}")
        except Exception as e:
            print(f"[{symbol}] error: {e}")
        time.sleep(SLEEP_BETWEEN)
    return (symbol, 0, "Error")

def load_symbols():
    with open(INPUT_FILE) as f:
        return [line.strip() for line in f if line.strip()]

def load_existing_results():
    if not os.path.exists(OUTPUT_FILE):
        return set()
    df = pd.read_csv(OUTPUT_FILE)
    return set(df['GeneSymbol'].values)

def save_result(symbol, count, status):
    with open(OUTPUT_FILE, "a") as f:
        f.write(f"{symbol},{count},{status}\n")

def main():
    all_symbols = load_symbols()
    done_symbols = load_existing_results()
    symbols_to_query = [s for s in all_symbols if s not in done_symbols]

    print(f"\n🧬 总基因数：{len(all_symbols)}")
    print(f"✅ 已处理：{len(done_symbols)}")
    print(f"🔍 待处理：{len(symbols_to_query)}")
    print(f"🚀 启动并发查询，线程数：{THREADS}\n")

    with open(OUTPUT_FILE, "a") as f:
        if os.stat(OUTPUT_FILE).st_size == 0:
            f.write("GeneSymbol,OrthologCount,Status\n")

    with ThreadPoolExecutor(max_workers=THREADS) as executor:
        future_to_symbol = {
            executor.submit(count_orthologs_by_symbol, symbol): symbol
            for symbol in symbols_to_query
        }

        for future in as_completed(future_to_symbol):
            symbol = future_to_symbol[future]
            try:
                result = future.result()
                save_result(*result)
                print(f"✅ {result[0]} → {result[1]} orthologs")
            except Exception as exc:
                print(f"❌ {symbol} exception: {exc}")
            time.sleep(SLEEP_BETWEEN)

    print(f"\n🎉 查询完成！结果保存在：{OUTPUT_FILE}")

if __name__ == "__main__":
    main()
# Out:
# 🧬 总基因数：12023
# ✅ 已处理：11289
# 🔍 待处理：734
# 🚀 启动并发查询，线程数：5
#
# ✅ Erbin → 184 orthologs
# ✅ Bmal1 → 179 orthologs
# ✅ Eloc → 149 orthologs
# ✅ H2az1 → 149 orthologs
# ✅ Patj → 166 orthologs
# [H2af] HTTP 400
# ✅ H4c16 → 12 orthologs
# ✅ Zfp24 → 107 orthologs
# [H2af] HTTP 400
# ✅ Eloa → 183 orthologs
# [H2af] HTTP 400
# ✅ H2af → 0 orthologs
# ✅ Skp1 → 149 orthologs
# ✅ Pea15b-ps → 0 orthologs
# ✅ Nherf4 → 143 orthologs
# ✅ Nherf1 → 139 orthologs
# ✅ Nherf2 → 138 orthologs
# ✅ Kmt5c → 165 orthologs
# ✅ H1f7 → 64 orthologs
# ✅ Sem1 → 144 orthologs
# ✅ Kmt5b → 188 orthologs
# ✅ Macroh2a3 → 0 orthologs
# ✅ Mesd → 194 orthologs
# ✅ Grk2 → 131 orthologs
# ✅ Diaph2 → 181 orthologs
# ✅ Plppr4 → 146 orthologs
# ✅ H1f4 → 86 orthologs
# ✅ Prag1 → 196 orthologs
# ✅ H2bc21 → 86 orthologs
# ✅ H4c14 → 136 orthologs
# ✅ Adgrv1 → 159 orthologs
# ✅ Nsd2 → 176 orthologs
# ✅ Ift25 → 124 orthologs
# ✅ Epb41l1 → 184 orthologs
# ✅ Ufd1 → 181 orthologs
# ✅ Vpreb1a → 3 orthologs
# ✅ Tamalin → 181 orthologs
# ✅ Septin4 → 176 orthologs
# ✅ Abraxas2 → 194 orthologs
# ✅ Kat14 → 196 orthologs
# ✅ Myorg → 109 orthologs
# ✅ Septin5 → 142 orthologs
# ✅ Septin2 → 182 orthologs
# ✅ Zftraf1 → 47 orthologs
# ✅ Septin7 → 153 orthologs
# ✅ Adss1 → 180 orthologs
# ✅ Cnot9 → 175 orthologs
# ✅ Afdn → 192 orthologs
# ✅ Cd300c2 → 16 orthologs
# ✅ Gcn1 → 197 orthologs
# ✅ Stxbp3 → 193 orthologs
# ✅ Epop → 97 orthologs
# ✅ Scn2a → 95 orthologs
# ✅ Marchf5 → 195 orthologs
# ✅ Nsmce3 → 20 orthologs
# ✅ Lilrb4b → 10 orthologs
# ✅ Pals1 → 150 orthologs
# ✅ H2ac18 → 14 orthologs
# ✅ Ripor2 → 193 orthologs
# ✅ Nemp1 → 180 orthologs
# ✅ Fyb1 → 178 orthologs
# ✅ Cibar1 → 176 orthologs
# ✅ Nectin4 → 137 orthologs
# ✅ H1f3 → 73 orthologs
# ✅ Angptl8 → 103 orthologs
# ✅ Tedc2 → 137 orthologs
# ✅ Hjv → 174 orthologs
# ✅ Rps23rg1 → 0 orthologs
# ✅ Shtn1 → 196 orthologs
# ✅ Paqr9 → 182 orthologs
# ✅ Ifi211 → 2 orthologs
# ✅ Sting1 → 185 orthologs
# ✅ Shoc1 → 147 orthologs
# ✅ Washc1 → 178 orthologs
# ✅ Nup58 → 198 orthologs
# ✅ Rack1 → 192 orthologs
# ✅ Ntaq1 → 193 orthologs
# ✅ Septin3 → 192 orthologs
# ✅ Wars1 → 204 orthologs
# ✅ Gon7 → 93 orthologs
# ✅ Ro60 → 202 orthologs
# ✅ H1f2 → 84 orthologs
# ✅ Selenoh → 48 orthologs
# ✅ Lars1 → 204 orthologs
# ✅ Selenop → 178 orthologs
# ✅ Rab1a → 148 orthologs
# ✅ Aars1 → 197 orthologs
# ✅ Mrpl58 → 155 orthologs
# ✅ Get3 → 176 orthologs
# ✅ Atp5pb → 163 orthologs
# ✅ Sars1 → 192 orthologs
# ✅ Gfus → 166 orthologs
# ✅ Plppr3 → 133 orthologs
# ✅ Epb41l2 → 194 orthologs
# ✅ Ero1a → 194 orthologs
# ✅ Atp5f1e → 87 orthologs
# ✅ Atp5f1a → 130 orthologs
# ✅ Atp5me → 123 orthologs
# ✅ Psme3ip1 → 171 orthologs
# ✅ Atp5pf → 141 orthologs
# ✅ Atp5f1b → 158 orthologs
# ✅ Rtraf → 184 orthologs
# ✅ Spart → 146 orthologs
# ✅ Epb41 → 147 orthologs
# ✅ Gba1 → 165 orthologs
# ✅ Epb41l3 → 149 orthologs
# ✅ Rars1 → 198 orthologs
# ✅ H1f1 → 89 orthologs
# ✅ Carnmt1 → 198 orthologs
# ✅ Ptpa → 191 orthologs
# ✅ Atp5if1 → 99 orthologs
# ✅ H2ac12 → 17 orthologs
# ✅ H2ac20 → 99 orthologs
# ✅ Nrdc → 132 orthologs
# ✅ Elob → 68 orthologs
# ✅ Eprs1 → 199 orthologs
# ✅ Trp53rkb → 7 orthologs
# ✅ Pals2 → 188 orthologs
# ✅ Hprt1 → 165 orthologs
# ✅ Cavin1 → 136 orthologs
# ✅ Atp5mf → 73 orthologs
# ✅ Atp5mk → 57 orthologs
# ✅ Atp5f1d → 191 orthologs
# ✅ Atp5f1c → 183 orthologs
# ✅ Cyrib → 136 orthologs
# ✅ Atp5mg → 15 orthologs
# ✅ Atp5pd → 131 orthologs
# ✅ Mcrip1 → 158 orthologs
# ✅ Ric8a → 183 orthologs
# ✅ Septin8 → 130 orthologs
# ✅ Rmc1 → 196 orthologs
# ✅ Hars1 → 101 orthologs
# ✅ Septin6 → 180 orthologs
# ✅ Hacd3 → 150 orthologs
# ✅ Septin9 → 139 orthologs
# ✅ Septin11 → 139 orthologs
# ✅ Jpt1 → 101 orthologs
# ✅ Prorp → 201 orthologs
# ✅ Mars1 → 203 orthologs
# ✅ mt-Atp8 → 42 orthologs
# ✅ Carmil2 → 113 orthologs
# ✅ Dmac2l → 199 orthologs
# ✅ Atp5po → 163 orthologs
# ✅ Gucy1b1 → 197 orthologs
# ✅ Gars1 → 176 orthologs
# ✅ Ark2n → 185 orthologs
# ✅ Kars1 → 186 orthologs
# ✅ Prune1 → 185 orthologs
# ✅ Tars1 → 200 orthologs
# ✅ Hdgfl2 → 180 orthologs
# ✅ Skic8 → 195 orthologs
# [Ptgr3] error: HTTPSConnectionPool(host='rest.ensembl.org', port=443): Read timed out. (read timeout=15)
# ✅ Ciao2b → 188 orthologs
# ✅ Hycc2 → 193 orthologs
# ✅ Eipr1 → 201 orthologs
# [Relch] error: HTTPSConnectionPool(host='rest.ensembl.org', port=443): Read timed out. (read timeout=15)
# ✅ Mrm3 → 110 orthologs
# ✅ Ptgr3 → 191 orthologs
# ✅ Grk3 → 191 orthologs
# ✅ Gyg1 → 130 orthologs
# ✅ Relch → 195 orthologs
# ✅ Dars1 → 202 orthologs
# ✅ Ppp4r3a → 193 orthologs
# ✅ Tkfc → 203 orthologs
# ✅ Ciao3 → 194 orthologs
# ✅ Prxl2b → 97 orthologs
# ✅ Cars1 → 193 orthologs
# ✅ Mtrex → 202 orthologs
# ✅ Pycr3 → 193 orthologs
# ✅ Adissp → 147 orthologs
# ✅ Dnaaf10 → 200 orthologs
# ✅ Ramac → 8 orthologs
# ✅ Ecpas → 202 orthologs
# ✅ Nars1 → 192 orthologs
# ✅ Mtres1 → 183 orthologs
# ✅ Efl1 → 191 orthologs
# ✅ Stn1 → 191 orthologs
# ✅ Tars3 → 187 orthologs
# ✅ Ctps1 → 150 orthologs
# ✅ Sdhaf3 → 158 orthologs
# ✅ Spout1 → 197 orthologs
# ✅ Utp25 → 206 orthologs
# ✅ Utp11 → 200 orthologs
# ✅ Abtb3 → 141 orthologs
# ✅ Ripor1 → 151 orthologs
# ✅ Adgrl1 → 174 orthologs
# ✅ Adgrb1 → 131 orthologs
# ✅ Qtrt2 → 199 orthologs
# ✅ Iqca1 → 195 orthologs
# ✅ Washc4 → 198 orthologs
# ✅ Kifbp → 194 orthologs
# ✅ Dcaf1 → 153 orthologs
# ✅ Washc5 → 203 orthologs
# ✅ Washc2 → 187 orthologs
# ✅ Ifi208 → 4 orthologs
# ✅ Matcap1 → 180 orthologs
# ✅ Bbln → 156 orthologs
# ✅ Acp3 → 112 orthologs
# ✅ Tut4 → 176 orthologs
# ✅ Rtl9 → 102 orthologs
# ✅ Odad1 → 47 orthologs
# ✅ Virma → 201 orthologs
# ✅ Bltp1 → 163 orthologs
# ✅ Sgo1 → 131 orthologs
# ✅ Dnai7 → 198 orthologs
# ✅ Diaph1 → 172 orthologs
# ✅ Sgo2a → 18 orthologs
# ✅ Cenps → 172 orthologs
# ✅ Chmp1b2 → 80 orthologs
# ✅ Togaram2 → 137 orthologs
# ✅ Bltp3b → 191 orthologs
# ✅ Ift70a2 → 8 orthologs
# ✅ Cblif → 130 orthologs
# ✅ Trir → 165 orthologs
# ✅ Hpf1 → 186 orthologs
# ✅ Dync2i2 → 200 orthologs
# ✅ Adgrl2 → 147 orthologs
# ✅ Atosb → 188 orthologs
# ✅ Epb41l4a → 169 orthologs
# ✅ Bud23 → 203 orthologs
# ✅ Eef1akmt2 → 200 orthologs
# ✅ Ccdc187 → 85 orthologs
# ✅ Styxl2 → 195 orthologs
# ✅ Jcad → 139 orthologs
# ✅ Zfp638 → 183 orthologs
# ✅ Disp3 → 188 orthologs
# ✅ Adgrl3 → 142 orthologs
# ✅ Garem2 → 184 orthologs
# ✅ Cep126 → 192 orthologs
# ✅ Ccn2 → 196 orthologs
# ✅ Slx9 → 183 orthologs
# ✅ B4gat1 → 186 orthologs
# ✅ Tasor → 156 orthologs
# ✅ Ncbp3 → 189 orthologs
# ✅ Ift56 → 192 orthologs
# ✅ Oga → 202 orthologs
# ✅ Ccn1 → 192 orthologs
# ✅ Cfap100 → 172 orthologs
# ✅ Adgrb2 → 181 orthologs
# ✅ Selenon → 103 orthologs
# ✅ Zup1 → 141 orthologs
# ✅ Map7d3 → 170 orthologs
# ✅ Carmil3 → 131 orthologs
# ✅ Nectin2 → 118 orthologs
# ✅ Tprg1l → 192 orthologs
# ✅ Cep20 → 190 orthologs
# ✅ Tektip1 → 111 orthologs
# ✅ Pcare → 159 orthologs
# ✅ Rubcn → 134 orthologs
# ✅ Khdc4 → 187 orthologs
# ✅ Cplane1 → 157 orthologs
# ✅ Spink1 → 100 orthologs
# ✅ P3h2 → 192 orthologs
# ✅ Nup42 → 187 orthologs
# ✅ Zng1 → 182 orthologs
# ✅ Adgrl4 → 202 orthologs
# ✅ Clcn4 → 183 orthologs
# ✅ Wapl → 149 orthologs
# ✅ Shfl → 125 orthologs
# ✅ Mrtfb → 145 orthologs
# ✅ Ccdc9b → 170 orthologs
# ✅ Odad3 → 150 orthologs
# ✅ Cfap210 → 106 orthologs
# ✅ Rxylt1 → 188 orthologs
# ✅ Gvin2 → 1 orthologs
# ✅ Get1 → 193 orthologs
# ✅ Drgx → 198 orthologs
# ✅ Iho1 → 130 orthologs
# ✅ Iars1 → 208 orthologs
# ✅ Tasor2 → 190 orthologs
# ✅ Ezhip → 17 orthologs
# ✅ Togaram1 → 184 orthologs
# ✅ Map3k20 → 150 orthologs
# ✅ Pclaf → 165 orthologs
# ✅ H2bc3 → 78 orthologs
# ✅ Obi1 → 46 orthologs
# ✅ Shld1 → 119 orthologs
# ✅ Cop1 → 196 orthologs
# ✅ Yars1 → 204 orthologs
# ✅ Wdr87-ps → 0 orthologs
# ✅ Cgas → 178 orthologs
# ✅ Dynlt2a2 → 1 orthologs
# ✅ H2bc8 → 18 orthologs
# ✅ Cfap47 → 103 orthologs
# ✅ Gatd3a → 191 orthologs
# ✅ Phb1 → 173 orthologs
# ✅ H3c13 → 28 orthologs
# ✅ Nipsnap2 → 140 orthologs
# ✅ mt-Cytb → 111 orthologs
# ✅ Micos13 → 175 orthologs
# ✅ Mix23 → 198 orthologs
# ✅ Atp5mj → 55 orthologs
# ✅ Coq8a → 144 orthologs
# ✅ Rcc1l → 196 orthologs
# ✅ Sqor → 187 orthologs
# ✅ Prxl2a → 94 orthologs
# ✅ Gk → 25 orthologs
# ✅ Plpbp → 190 orthologs
# ✅ Etfrf1 → 146 orthologs
# ✅ Mtarc2 → 163 orthologs
# ✅ Gapdh-ps15 → 0 orthologs
# ✅ Naxe → 188 orthologs
# ✅ Fmc1 → 167 orthologs
# ✅ Kyat3 → 203 orthologs
# ✅ Micos10 → 144 orthologs
# ✅ Mtrfr → 191 orthologs
# ✅ Marchf7 → 188 orthologs
# ✅ H2ac13 → 4 orthologs
# ✅ Mrtfa → 124 orthologs
# ✅ Slf1 → 185 orthologs
# ✅ Emsy → 194 orthologs
# ✅ Resf1 → 135 orthologs
# ✅ H3c6 → 48 orthologs
# ✅ H4c2 → 30 orthologs
# ✅ Taf4 → 145 orthologs
# ✅ H2bc26 → 32 orthologs
# ✅ Mideas → 133 orthologs
# ✅ Krt90 → 86 orthologs
# ✅ Borcs5 → 194 orthologs
# ✅ Bicra → 165 orthologs
# ✅ Colgalt1 → 131 orthologs
# ✅ Mindy4 → 198 orthologs
# ✅ Gapdhrt2 → 1 orthologs
# ✅ Mrip-ps → 0 orthologs
# ✅ Gapdh-ps14 → 0 orthologs
# ✅ Gapdh-ps16 → 0 orthologs
# ✅ Gapdhrt → 0 orthologs
# ✅ H2bc18 → 82 orthologs
# ✅ Cbr1b → 3 orthologs
# ✅ Polr1g → 163 orthologs
# ✅ Dnaaf4 → 185 orthologs
# ✅ H4c8 → 15 orthologs
# ✅ H4c3 → 30 orthologs
# ✅ H3c7 → 8 orthologs
# ✅ H4c12 → 12 orthologs
# ✅ H2ac21 → 93 orthologs
# ✅ H2ac25 → 91 orthologs
# ✅ Cdk3 → 134 orthologs
# ✅ Kmt5a → 91 orthologs
# ✅ Cimip1 → 149 orthologs
# ✅ Spmip5 → 115 orthologs
# ✅ Rab7b → 133 orthologs
# ✅ Cep295nl → 52 orthologs
# ✅ Cfap418 → 191 orthologs
# ✅ H2bc4 → 18 orthologs
# ✅ H1f5 → 83 orthologs
# ✅ Sgf29 → 172 orthologs
# ✅ Nop53 → 177 orthologs
# ✅ Niban1 → 147 orthologs
# ✅ Tent2 → 203 orthologs
# ✅ Bex3 → 78 orthologs
# ✅ Nsd3 → 187 orthologs
# ✅ Vegfd → 189 orthologs
# ✅ H2bc13 → 5 orthologs
# ✅ Myo15a → 123 orthologs
# ✅ H4c1 → 12 orthologs
# ✅ Prss3b → 30 orthologs
# ✅ Akr1b1 → 92 orthologs
# ✅ Utp4 → 198 orthologs
# ✅ Epb41l5 → 196 orthologs
# ✅ Ftl1-ps1 → 0 orthologs
# ✅ Rexo5 → 176 orthologs
# ✅ Iqcm → 80 orthologs
# ✅ Pramel25 → 3 orthologs
# ✅ Pramel15 → 21 orthologs
# ✅ Armh3 → 197 orthologs
# ✅ H2aj → 91 orthologs
# ✅ Hectd4 → 191 orthologs
# ✅ Tmt1b → 107 orthologs
# ✅ Ints13 → 206 orthologs
# ✅ Ints14 → 208 orthologs
# ✅ Vars1 → 173 orthologs
# ✅ Snu13 → 146 orthologs
# ✅ Pum3 → 197 orthologs
# ✅ Riox1 → 170 orthologs
# ✅ Hacd2 → 187 orthologs
# ✅ Vps35l → 201 orthologs
# ✅ Cip2a → 197 orthologs
# ✅ Elp1 → 147 orthologs
# ✅ H2bc14 → 67 orthologs
# ✅ Niban2 → 149 orthologs
# ✅ Cops9 → 20 orthologs
# ✅ H3c1 → 52 orthologs
# ✅ H2az2 → 162 orthologs
# [Olfm5] error: HTTPSConnectionPool(host='rest.ensembl.org', port=443): Read timed out. (read timeout=15)
# ✅ Mfsd14b → 140 orthologs
# ✅ H3c4 → 47 orthologs
# ✅ H4c4 → 27 orthologs
# ✅ Kirrel1 → 137 orthologs
# ✅ Adgra1 → 184 orthologs
# ✅ Olfm5 → 54 orthologs
# ✅ Plpp3 → 146 orthologs
# ✅ Adgrb3 → 191 orthologs
# ✅ Carmil1 → 145 orthologs
# ✅ Znrd2 → 178 orthologs
# ✅ Abraxas1 → 179 orthologs
# ✅ Tcstv1b → 0 orthologs
# ✅ Tcstv1a → 0 orthologs
# ✅ Vcf1 → 98 orthologs
# ✅ Adrm1b → 11 orthologs
# ✅ Misp3 → 120 orthologs
# ✅ mt-Nd4 → 97 orthologs
# ✅ mt-Nd5 → 106 orthologs
# ✅ Jaml → 83 orthologs
# ✅ Mtcl3 → 144 orthologs
# ✅ Mtcl2 → 147 orthologs
# ✅ Pak5 → 190 orthologs
# ✅ Fhip2b → 176 orthologs
# ✅ H2ac10 → 6 orthologs
# ✅ Prss59 → 77 orthologs
# ✅ Jchain → 139 orthologs
# ✅ Or52ae7 → 21 orthologs
# ✅ H2bc23 → 0 orthologs
# ✅ Gramd2b → 160 orthologs
# ✅ Tent5a → 145 orthologs
# ✅ Selenos → 114 orthologs
# ✅ Selenof → 62 orthologs
# ✅ Smim26 → 82 orthologs
# ✅ H2bc1 → 100 orthologs
# ✅ Cyria → 196 orthologs
# ✅ Prxl2c → 183 orthologs
# ✅ Meioc → 146 orthologs
# ✅ Afg2a → 204 orthologs
# ✅ Irgc → 103 orthologs
# ✅ Flvcr2 → 140 orthologs
# ✅ Magea13 → 52 orthologs
# ✅ Irag2 → 191 orthologs
# ✅ Epb42 → 129 orthologs
# ✅ Adgre5 → 153 orthologs
# ✅ Adgre1 → 103 orthologs
# ✅ Tcstv2c → 0 orthologs
# ✅ Tcstv2a → 0 orthologs
# ✅ Rp2 → 195 orthologs
# ✅ Cert1 → 144 orthologs
# ✅ Ifi209 → 8 orthologs
# ✅ Arhgap45 → 171 orthologs
# ✅ Bpnt2 → 147 orthologs
# ✅ Tent4b → 195 orthologs
# ✅ Faap20 → 86 orthologs
# ✅ Faap24 → 183 orthologs
# ✅ Acod1 → 197 orthologs
# ✅ Mtss2 → 139 orthologs
# ✅ Tcaf1 → 98 orthologs
# ✅ Rtf2 → 200 orthologs
# ✅ Jhy → 154 orthologs
# ✅ Bltp2 → 190 orthologs
# ✅ H1f6 → 73 orthologs
# ✅ Tedc1 → 124 orthologs
# ✅ Poglut3 → 186 orthologs
# ✅ Elapor2 → 139 orthologs
# ✅ Cwc22rt7 → 0 orthologs
# ✅ Cwc22rt3 → 1 orthologs
# ✅ Iftap → 129 orthologs
# ✅ Ppp1ccb → 193 orthologs
# ✅ C9orf72 → 195 orthologs
# ✅ Tcaf2 → 97 orthologs
# ✅ Naxd → 197 orthologs
# ✅ Inka2 → 179 orthologs
# ✅ Ldah → 190 orthologs
# ✅ Faap100 → 194 orthologs
# ✅ Tns2 → 120 orthologs
# ✅ Marchf11 → 180 orthologs
# ✅ H2bc6 → 25 orthologs
# ✅ Pudp → 185 orthologs
# ✅ Atpsckmt → 193 orthologs
# ✅ H4c17 → 15 orthologs
# ✅ H4c6 → 17 orthologs
# ✅ Ndufb4c → 0 orthologs
# ✅ H4c9 → 23 orthologs
# ✅ Ndufb4b → 173 orthologs
# ✅ H4c11 → 17 orthologs
# ✅ H4c18 → 2 orthologs
# ✅ Hmga1b → 63 orthologs
# ✅ Entrep1 → 176 orthologs
# ✅ Vps50 → 202 orthologs
# ✅ Septin1 → 106 orthologs
# ✅ Steep1 → 180 orthologs
# ✅ Polr1f → 187 orthologs
# ✅ Srpra → 200 orthologs
# ✅ Nsrp1 → 196 orthologs
# ✅ Pym1 → 187 orthologs
# ✅ Rps18-ps6 → 27 orthologs
# ✅ Tut7 → 159 orthologs
# ✅ Ct55 → 35 orthologs
# ✅ Twnk → 195 orthologs
# ✅ H2bc24 → 0 orthologs
# ✅ H2af-ps2 → 0 orthologs
# ✅ H3c2 → 72 orthologs
# ✅ H3c14 → 22 orthologs
# ✅ H3c3 → 8 orthologs
# [Gm21992] error: list index out of range
# ✅ Arpin → 176 orthologs
# ✅ H3c15 → 14 orthologs
# ✅ Ahcyl → 11 orthologs
# [Gm21992] error: list index out of range
# ✅ Hsd17b8 → 171 orthologs
# ✅ Cracdl → 129 orthologs
# ✅ Fdx2 → 178 orthologs
# [Gm21992] error: list index out of range
# ✅ Ciao2a → 192 orthologs
# ✅ H2bc22 → 9 orthologs
# ✅ Gm21992 → 0 orthologs
# ✅ Hikeshi → 184 orthologs
# ✅ Hdgfl3 → 168 orthologs
# ✅ H2bc27 → 40 orthologs
# ✅ Golm2 → 183 orthologs
# ✅ Hdhd5 → 197 orthologs
# ✅ Jpt2 → 183 orthologs
# ✅ Selenoo → 162 orthologs
# ✅ Mindy1 → 189 orthologs
# ✅ Mydgf → 181 orthologs
# ✅ Nectin1 → 144 orthologs
# ✅ Adgra3 → 196 orthologs
# ✅ Septin14 → 96 orthologs
# ✅ Cfap298 → 201 orthologs
# ✅ Flacc1 → 101 orthologs
# ✅ Fam243 → 108 orthologs
# ✅ Adgrf5 → 145 orthologs
# ✅ Diaph3 → 193 orthologs
# ✅ Dnai1 → 194 orthologs
# ✅ Dusp13a → 65 orthologs
# ✅ Drc3 → 117 orthologs
# ✅ Fhip2a → 203 orthologs
# ✅ Dipk1a → 146 orthologs
# ✅ Haspin → 169 orthologs
# ✅ Poglut2 → 204 orthologs
# ✅ Llcfc1 → 77 orthologs
# ✅ Matcap2 → 177 orthologs
# ✅ Pimreg → 161 orthologs
# ✅ Cfap91 → 203 orthologs
# ✅ Slf2 → 191 orthologs
# ✅ Dennd2b → 189 orthologs
# ✅ Thap12 → 120 orthologs
# ✅ Spmap2l → 109 orthologs
# ✅ Odad4 → 187 orthologs
# ✅ Cavin4 → 141 orthologs
# ✅ Pip4p2 → 197 orthologs
# ✅ Ints6l → 136 orthologs
# ✅ Fhip1b → 186 orthologs
# ✅ Kif28 → 117 orthologs
# ✅ Cracd → 173 orthologs
# ✅ Ajm1 → 113 orthologs
# ✅ Gatd1 → 103 orthologs
# ✅ Or52j3 → 52 orthologs
# ✅ Cavin3 → 104 orthologs
# ✅ Cdin1 → 196 orthologs
# ✅ Polr1h → 180 orthologs
# ✅ Retreg3 → 122 orthologs
# ✅ Selenoi → 198 orthologs
# ✅ Wdr97 → 87 orthologs
# ✅ Dusp29 → 153 orthologs
# ✅ Mrm2 → 191 orthologs
# ✅ Dnaaf5 → 195 orthologs
# ✅ Cramp1 → 196 orthologs
# ✅ Cfap20dc → 172 orthologs
# ✅ Yju2 → 188 orthologs
# ✅ Ift70b → 16 orthologs
# ✅ Sp140l2 → 0 orthologs
# ✅ Nhsl3 → 160 orthologs
# ✅ Tmem94 → 197 orthologs
# ✅ Slc66a3 → 188 orthologs
# ✅ Dync2i1 → 195 orthologs
# ✅ Cybc1 → 184 orthologs
# ✅ H2bc7 → 5 orthologs
# ✅ H2bc11 → 2 orthologs
# ✅ H2bc15 → 3 orthologs
# ✅ Erg28 → 196 orthologs
# ✅ Selenot → 181 orthologs
# ✅ Macroh2a2 → 192 orthologs
# ✅ Odr4 → 194 orthologs
# ✅ Tmem121b → 136 orthologs
# ✅ Mcub → 135 orthologs
# ✅ mt-Nd4l → 35 orthologs
# ✅ mt-Nd2 → 95 orthologs
# ✅ Maip1 → 190 orthologs
# [Cavin2] error: HTTPSConnectionPool(host='rest.ensembl.org', port=443): Read timed out. (read timeout=15)
# ✅ Dglucy → 165 orthologs
# ✅ mt-Nd3 → 92 orthologs
# ✅ Atp5mc2 → 46 orthologs
# ✅ Or2ag1b → 19 orthologs
# ✅ Cavin2 → 134 orthologs
# ✅ H2ac6 → 1 orthologs
# ✅ H2ac7 → 1 orthologs
# ✅ H2ac8 → 5 orthologs
# ✅ H2ac22 → 5 orthologs
# ✅ H2ac24 → 3 orthologs
# ✅ H2ac11 → 0 orthologs
# ✅ H2ac4 → 10 orthologs
# ✅ H2ac23 → 0 orthologs
# ✅ Calhm5 → 178 orthologs
# ✅ Rpl6l → 0 orthologs
# ✅ Zfp998 → 0 orthologs
# [Or13j1] error: HTTPSConnectionPool(host='rest.ensembl.org', port=443): Read timed out. (read timeout=15)
# ✅ Psma5-ps → 0 orthologs
# ✅ Nexmif → 184 orthologs
# ✅ Plpp2 → 126 orthologs
# [Rpl37rt] error: HTTPSConnectionPool(host='rest.ensembl.org', port=443): Read timed out. (read timeout=15)
# ✅ Taf9-ps → 0 orthologs
# ✅ Or13j1 → 77 orthologs
# ✅ Plpp1 → 143 orthologs
# ✅ Rpl37rt → 127 orthologs
# ✅ Shld2 → 166 orthologs
# ✅ Tspoap1 → 126 orthologs
# ✅ Marchf8 → 200 orthologs
# ✅ Dop1a → 174 orthologs
# ✅ Tasl → 190 orthologs
# ✅ Stimate → 184 orthologs
# ✅ Mfsd14a → 150 orthologs
# ✅ Plpp5 → 188 orthologs
# ✅ Flvcr1 → 188 orthologs
# ✅ Pheta1 → 98 orthologs
# ✅ Gpat4 → 150 orthologs
# ✅ Nectin3 → 134 orthologs
# ✅ Pcnx3 → 173 orthologs
# ✅ Tmem185a → 168 orthologs
# ✅ H2bc9 → 60 orthologs
# ✅ Lrmda → 194 orthologs
# ✅ Marchf6 → 156 orthologs
# ✅ Brme1 → 93 orthologs
# ✅ Maco1 → 147 orthologs
# ✅ Rida → 125 orthologs
# ✅ Cemip2 → 196 orthologs
# ✅ Tmem131l → 189 orthologs
# ✅ Czib → 198 orthologs
# ✅ Rusf1 → 186 orthologs
# ✅ Rab5if → 190 orthologs
# ✅ Otulinl → 138 orthologs
# ✅ Nemp2 → 148 orthologs
# ✅ Retreg1 → 138 orthologs
# ✅ Atp5mc1 → 67 orthologs
# ✅ Nopchap1 → 97 orthologs
# ✅ Retreg2 → 93 orthologs
# ✅ Mtln → 141 orthologs
# ✅ Selenom → 186 orthologs
# ✅ H1f10 → 120 orthologs
# ✅ Btbd35f1 → 0 orthologs
# ✅ Septin10 → 174 orthologs
# ✅ Spaca7b → 24 orthologs
# ✅ Kyat1 → 186 orthologs
# ✅ Ccdc196 → 88 orthologs
# ✅ Ccdc121 → 23 orthologs
# ✅ Sanbr → 197 orthologs
# ✅ Arfgef3 → 194 orthologs
# ✅ Cbarp → 123 orthologs
# ✅ Ifit3b → 0 orthologs
# ✅ Plppr2 → 127 orthologs
# ✅ H3c8 → 56 orthologs
# ✅ Hdac1-ps → 0 orthologs
# ✅ mt-Atp6 → 91 orthologs
# ✅ Tmem35a → 183 orthologs
# ✅ Fam91a1 → 188 orthologs
# ✅ Ints11 → 196 orthologs
# ✅ Epb41l4b → 191 orthologs
# ✅ Chi3l1 → 107 orthologs
# ✅ Minar1 → 193 orthologs
# ✅ Slc45a2 → 201 orthologs
# ✅ H2ac19 → 57 orthologs
# ✅ Phf24 → 187 orthologs
# ✅ Cryzl2 → 103 orthologs
# ✅ mt-Co3 → 99 orthologs
# ✅ Pnma8b → 53 orthologs
# ✅ Rtl8b → 7 orthologs
# ✅ Cimap3 → 161 orthologs
# ✅ Stum → 193 orthologs
# ✅ Or52e2 → 52 orthologs
# ✅ Pramel13os → 0 orthologs
# ✅ Fam3d → 193 orthologs
# ✅ Actc1dt → 10 orthologs
# ✅ Magea14 → 19 orthologs
# ✅ Fam25a → 88 orthologs
# ✅ Saxo4 → 122 orthologs
# ✅ Pramel12 → 24 orthologs
# ✅ Acsbg3 → 46 orthologs
# ✅ Marchf4 → 182 orthologs
# ✅ Smkr-ps → 0 orthologs
# ✅ Bclaf3 → 178 orthologs
# ✅ Eola1 → 150 orthologs
# ✅ Ccdc121rt3 → 22 orthologs
# ✅ Rtl5 → 83 orthologs
# ✅ Or6x1 → 72 orthologs
# ✅ Smim10l2a → 37 orthologs
# ✅ Cimap2 → 122 orthologs
# ✅ Sox1ot → 7 orthologs
# ✅ Tafa5 → 135 orthologs
# ✅ Tsbp1 → 62 orthologs
# ✅ Or7g28 → 18 orthologs
# ✅ Or5b106 → 20 orthologs
# ✅ Ndufb11b → 18 orthologs
# ✅ Unc93a2 → 0 orthologs
# ✅ Prr23a2 → 8 orthologs
# ✅ Platr26 → 0 orthologs
# ✅ Ct45a → 46 orthologs
# ✅ Rtl8a → 7 orthologs
# ✅ Mfsd4b3-ps → 0 orthologs
# ✅ Insyn1 → 183 orthologs
# ✅ Semp2l2b → 4 orthologs
# ✅ Mir100hg → 6 orthologs
# ✅ Tektl1 → 115 orthologs
# ✅ Nalf1 → 138 orthologs
# ✅ Pramel14 → 0 orthologs
# ✅ Ctag2l1 → 0 orthologs
# ✅ Tm9sf5 → 136 orthologs
# ✅ Rhox2-ps → 0 orthologs
# ✅ Nme-ps1 → 0 orthologs
# ✅ Snrpert → 0 orthologs
# ✅ Rpl7-ps9 → 0 orthologs
# ✅ Tslrn1 → 0 orthologs
# ✅ Mexis → 0 orthologs
# ✅ Ndufs6b → 0 orthologs
# ✅ Lexis1 → 0 orthologs
# ✅ Slfnlnc → 0 orthologs
# ✅ Mir503hg → 0 orthologs
# ✅ Dnmt3c → 3 orthologs
# ✅ Tcstv7a → 2 orthologs
# ✅ Platr7 → 0 orthologs
# ✅ Kcne5 → 96 orthologs
# ✅ Platr21 → 13 orthologs
# ✅ Platr5 → 0 orthologs
# ✅ Eif1ad10 → 0 orthologs
# ✅ Pnma6e → 1 orthologs
# ✅ Rbm3-ps → 0 orthologs
# ✅ Phf20-ps → 0 orthologs
# ✅ Mir124a-1hg → 16 orthologs
# ✅ Gstp-ps → 0 orthologs
# ✅ Gm38509 → 6 orthologs
# ✅ Dynlt2a3 → 1 orthologs
# ✅ Depp1 → 98 orthologs
# ✅ Prelid3a → 186 orthologs
# ✅ Sdhaf4 → 179 orthologs
# ✅ Or5b121 → 6 orthologs
# ✅ Fcgbpl1 → 18 orthologs
# ✅ Efcab3 → 68 orthologs
# ✅ Qars1 → 196 orthologs
# ✅ Card19 → 98 orthologs
# ✅ Tcim → 177 orthologs
# ✅ Tlcd4 → 181 orthologs
# ✅ Atp23 → 197 orthologs
# ✅ Sinhcaf → 159 orthologs
# ✅ Atosa → 194 orthologs
# ✅ Tmem268 → 192 orthologs
# ✅ Qki → 189 orthologs
# ✅ Lin28b → 186 orthologs
# ✅ Celf6 → 180 orthologs
# ✅ Sele → 135 orthologs
# ✅ Alkbh1 → 198 orthologs
# ✅ Mfsd12 → 169 orthologs
#
# 🎉 查询完成！结果保存在：all_species_ortholog_counts.csv

# %% [markdown]
# Step2.2.3 Annotate ortholog count

# %%
import pandas as pd

orthologs_counts = pd.read_csv('all_species_ortholog_counts.csv')
protein = pd.read_csv('proteins.csv')

orthologs_counts = orthologs_counts[orthologs_counts['Status']=='OK']
orthologs_counts = orthologs_counts[['GeneSymbol','OrthologCount']]
protein_orthologs_counts = pd.merge(protein,orthologs_counts,left_on='protein',right_on='GeneSymbol',how='inner')
protein_orthologs_counts = protein_orthologs_counts[['protein_ID','OrthologCount']]
protein_orthologs_counts.to_csv("protein_orthologs_counts.csv",index=False)

# %% [markdown]
# ### Step2.3 Annotate the expression feature.

# %% [markdown]
# Step2.3.1 Calculate avg_TPM of gene at 22 tissues.

# %%
import pandas as pd

exp_file = pd.read_csv("../../protein/mouse/filtered_exp.csv")

# 确保列名正确（避免大小写或空格问题）
exp_file.columns = exp_file.columns.str.strip()

# 先按 `Gene Symbol` 和 `Anatomical Structure` 计算 `avg_TPM` 均值
grouped_avg = exp_file.groupby(['Gene Symbol', 'Anatomical Structure'])['avg_TPM'].mean().reset_index()
grouped_avg.rename(columns={'avg_TPM': 'Mean_avg_TPM'}, inplace=True)

# 再按 `Gene Symbol` 计算这些均值的 中位数 和 均值
final_stats = grouped_avg.groupby('Gene Symbol')['Mean_avg_TPM'].agg(['median', 'mean']).reset_index()
final_stats.rename(columns={'median': 'Median_avg_TPM', 'mean': 'Mean_avg_TPM'}, inplace=True)

final_stats.to_csv("exp.csv",index=False)
# Out:
# /tmp/ipykernel_1016/345623464.py:3: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   exp_file = pd.read_csv("../../protein/mouse/filtered_exp.csv")

# %% [markdown]
# step2.3.2 Annotate the mean&media of expression at 22 tissues.

# %%
import pandas as pd
exp_file = pd.read_csv("exp.csv")
protein = pd.read_csv("proteins.csv", dtype=str)
protein_exp = pd.merge(protein, exp_file, left_on='protein', right_on='Gene Symbol', how='inner')

# 将结果保存到文件
protein_exp = protein_exp[['protein_ID','Median_avg_TPM','Mean_avg_TPM']]
protein_exp.to_csv("protein_exp.csv", sep=",", index=False)

# %% [markdown]
# ## Step3 Merge annotation.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

exp_anno = pd.read_csv("protein_exp.csv")
go_anno = pd.read_csv("protein_go_term_counts.csv")
homo_anno = pd.read_csv("protein_orthologs_counts.csv")

protein_annotation = pd.merge(exp_anno, go_anno, on='protein_ID', how="inner")
protein_annotation = protein_annotation.merge(homo_anno, on="protein_ID", how='inner')

first_column = protein_annotation.iloc[:, [0]]
other_columns = protein_annotation.iloc[:, 1:]

scaler = StandardScaler()
normalized_data = scaler.fit_transform(other_columns)

df_normalized = pd.concat([first_column, pd.DataFrame(normalized_data, columns=other_columns.columns)], axis=1)

df_normalized.to_csv("transformed_protein_annotation.csv",index=False)

# %% [markdown]
# ### Step3.2 Get inter with valid protein.

# %%
import pandas as pd

inter = pd.read_csv("inter_with_valid_lnc.csv")
valid_protein = pd.read_csv("transformed_protein_annotation.csv")

valid_protein_set = set(valid_protein['protein_ID'])

# 定义函数检查以'p'开头的节点是否在valid_protein中
def check_valid_protein(node):
    if node.startswith('p'):
        return node in valid_protein_set
    return True  # 若不以'p'开头，保留该节点

# 逐行检查Node_i和Node_j是否有效
inter = inter[inter['Node_i'].apply(check_valid_protein) & inter['Node_j'].apply(check_valid_protein)]

inter.to_csv("valid_inter.csv", index=False)

#cell_lines = ['CH12.LX','ES-E14','MEL', 'ac']
tissues = ['brain']
for tissue in tissues:
	lnc = pd.read_csv(f"{tissue}_annotation.csv")
	lnc = lnc[lnc['lncRNA_ID'].isin(inter['Node_i'])]

	lnc.to_csv(f"valid_{tissue}_annotation.csv", index=False)

# %% [markdown]
# ## Step4 Calculate edge wight.

# %%
import pandas as pd

# Read the input CSV file
inter = pd.read_csv("valid_inter.csv")

# Ensure (Node_i, Node_j) and (Node_j, Node_i) are considered the same edge
# Sort each pair so that the smaller node always comes first
inter[['Node_i', 'Node_j']] = inter[['Node_i', 'Node_j']].apply(lambda x: tuple(sorted(x)), axis=1, result_type='expand')

# Compute the weight (number of occurrences of each edge)
inter['weight'] = inter.groupby(['Node_i', 'Node_j']).transform('size')

# Remove duplicate edges, keeping only one occurrence per (Node_i, Node_j) pair
inter = inter.drop_duplicates(subset=['Node_i', 'Node_j'])

inter.columns = ['source', 'target', 'weight']

# Save the weighted edge list to a new CSV file
inter.to_csv('weighted_valid_inter.csv', index=False)

print("Weighted interaction file has been successfully saved!")
# Out:
# Weighted interaction file has been successfully saved!

# %%
import pandas as pd 

lppi = pd.read_csv("valid_inter.csv")

# 根据第一列前缀是否为 'l' 来划分 LPI 和 PPI
LPI = lppi[lppi.iloc[:, 0].str.startswith('l')]
PPI = lppi[~lppi.iloc[:, 0].str.startswith('l')]

# 统计LPI中lncRNA、protein数量和边数量
lncRNA_count_LPI = LPI.iloc[:, 0].nunique()
protein_count_LPI = LPI.iloc[:, 1].nunique()
edges_count_LPI = len(LPI)

# 统计PPI中protein数量和边数量（两列均为protein）
protein_count_PPI = pd.unique(PPI.iloc[:, [0, 1]].values.ravel()).size
edges_count_PPI = len(PPI)

# 输出统计结果
print("LPI统计结果：")
print(f"lncRNA数量：{lncRNA_count_LPI}")
print(f"protein数量：{protein_count_LPI}")
print(f"边的数量：{edges_count_LPI}")

print("\nPPI统计结果：")
print(f"protein数量：{protein_count_PPI}")
print(f"边的数量：{edges_count_PPI}")
# Out:
# LPI统计结果：
# lncRNA数量：37658
# protein数量：177
# 边的数量：135107
#
# PPI统计结果：
# protein数量：11489
# 边的数量：76095

# %%
import pandas as pd

# 读取 CSV 文件
# 假设 CSV 中前两列为节点（即边）
df = pd.read_csv('weighted_valid_inter.csv')

# 统计每个节点的度
node_degrees = pd.concat([df['source'], df['target']]).value_counts()

# 分别提取 l 开头和 p 开头的节点
l_nodes = node_degrees[node_degrees.index.str.startswith('l')]
p_nodes = node_degrees[node_degrees.index.str.startswith('p')]

# 计算 l 开头节点的度的范围和均值
l_degree_range = (l_nodes.min(), l_nodes.max())
l_degree_mean = l_nodes.mean()

# 计算 p 开头节点的度的范围和均值
p_degree_range = (p_nodes.min(), p_nodes.max())
p_degree_mean = p_nodes.mean()

# 打印结果
print(f"l 开头节点度的范围：{l_degree_range}")
print(f"l 开头节点度的均值：{l_degree_mean}")

print(f"\np 开头节点度的范围：{p_degree_range}")
print(f"p 开头节点度的均值：{p_degree_mean}")
# Out:
# l 开头节点度的范围：(1, 93)
# l 开头节点度的均值：3.019411546019438
#
# p 开头节点度的范围：(1, 24508)
# p 开头节点度的均值：21.73330434782609
